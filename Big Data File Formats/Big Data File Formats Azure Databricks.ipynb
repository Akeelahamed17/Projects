# %% [markdown]
# ### Step 1: Set the Storage Account Name & Access Key
#
# In order to access data from Azure storage, we need to first provide the storage account name and access key.

# %%
storage_account_name = "taxistorage2019"
storage_account_access_key = "########"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Set up the Storage Account Access key.

# %%
spark.conf.set(
  "fs.azure.account.key."+storage_account_name+".blob.core.windows.net",
  storage_account_access_key)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 2: Read the data
#
# Now that we have specified our file metadata, we can create a DataFrame. Notice that we use an *option* to specify that we want to infer the schema from the file. We can also explicitly set this to a particular schema if we have one already.
#
# First, let's create a DataFrame in Python.

# %%
#
dfTaxi = spark.read.format("csv").option("header", "true").option("inferschema", "true").load("wasbs://taxicab@taxistorage2019.blob.core.windows.net/train.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ###Step 3: Save the Data
#
# We save two different copies of the data for comparison of speed to run queries: One in csv, avro, and parquet.

# %%
dfTaxi.write.mode("overwrite").option("header", "true").format("csv").saveAsTable("TaxiCSV")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfTaxi.write.mode("overwrite").option("header", "true").format("avro").saveAsTable("TaxiAvro")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfTaxi.write.mode("overwrite").option("header", "true").format("parquet").saveAsTable("TaxiParquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfTaxi.write.mode("overwrite").option("header", "true").format("orc").saveAsTable("TaxiORC")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# We can query this view using Spark SQL. For instance, we can perform a simple aggregation. Notice how we can use `%sql` to query the view from SQL.

# %%
# %sql
--CSV
SELECT COUNT(*) from TaxiCSV
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>1710670</td></tr></tbody></table></div>

# %%
# %sql
--Avro
SELECT COUNT(*) FROM TaxiAvro
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>1710670</td></tr></tbody></table></div>

# %%
# %sql
--Parquet
SELECT COUNT(*) FROM TaxiParquet
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>1710670</td></tr></tbody></table></div>

# %%
# %sql
--ORC
SELECT COUNT(*) FROM TaxiORC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>1710670</td></tr></tbody></table></div>

# %% [markdown]
# ###More complex query examples

# %% [markdown]
# #### Example 1

# %%
# %sql
SELECT SUM(Case when DAY_TYPE = 'B' then 1 else 0 end) as Trips_On_Holiday
      , SUM(Case when DAY_TYPE = 'C' then 1 else 0 end) as Trips_Before_Holiday
      , SUM(Case when DAY_TYPE = 'A' then 1 else 0 end) as Trips_On_NormalDays
FROM TaxiCSV
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Trips_On_Holiday</th><th>Trips_Before_Holiday</th><th>Trips_On_NormalDays</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>1710670</td></tr></tbody></table></div>

# %%
# %sql
SELECT SUM(Case when DAY_TYPE = 'B' then 1 else 0 end) as Trips_On_Holiday
      , SUM(Case when DAY_TYPE = 'C' then 1 else 0 end) as Trips_Before_Holiday
      , SUM(Case when DAY_TYPE = 'A' then 1 else 0 end) as Trips_On_NormalDays
FROM TaxiAvro
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Trips_On_Holiday</th><th>Trips_Before_Holiday</th><th>Trips_On_NormalDays</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>1710670</td></tr></tbody></table></div>

# %%
# %sql
SELECT SUM(Case when DAY_TYPE = 'B' then 1 else 0 end) as Trips_On_Holiday
      , SUM(Case when DAY_TYPE = 'C' then 1 else 0 end) as Trips_Before_Holiday
      , SUM(Case when DAY_TYPE = 'A' then 1 else 0 end) as Trips_On_NormalDays
FROM taxiparquet
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Trips_On_Holiday</th><th>Trips_Before_Holiday</th><th>Trips_On_NormalDays</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>1710670</td></tr></tbody></table></div>

# %%
# %sql
SELECT SUM(Case when DAY_TYPE = 'B' then 1 else 0 end) as Trips_On_Holiday
      , SUM(Case when DAY_TYPE = 'C' then 1 else 0 end) as Trips_Before_Holiday
      , SUM(Case when DAY_TYPE = 'A' then 1 else 0 end) as Trips_On_NormalDays
FROM taxiorc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Trips_On_Holiday</th><th>Trips_Before_Holiday</th><th>Trips_On_NormalDays</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>1710670</td></tr></tbody></table></div>

# %% [markdown]
# ####Example 2

# %%
re%sql
SELECT SUM(Case when MISSING_DATA = false then 1 else 0 end) as No_Missing_Data
      , SUM(Case when MISSING_DATA = true then 1 else 0 end) as Missing_Data
FROM taxicsv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>No_Missing_Data</th><th>Missing_Data</th></tr></thead><tbody><tr><td>1710660</td><td>10</td></tr></tbody></table></div>

# %%
# %sql
SELECT SUM(Case when MISSING_DATA = false then 1 else 0 end) as No_Missing_Data
      , SUM(Case when MISSING_DATA = true then 1 else 0 end) as Missing_Data
FROM taxiparquet
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>No_Missing_Data</th><th>Missing_Data</th></tr></thead><tbody><tr><td>1710660</td><td>10</td></tr></tbody></table></div>

# %%
# %sql
SELECT SUM(Case when MISSING_DATA = false then 1 else 0 end) as No_Missing_Data
      , SUM(Case when MISSING_DATA = true then 1 else 0 end) as Missing_Data
FROM taxiorc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>No_Missing_Data</th><th>Missing_Data</th></tr></thead><tbody><tr><td>1710660</td><td>10</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM taxiorc 
limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TRIP_ID</th><th>CALL_TYPE</th><th>ORIGIN_CALL</th><th>ORIGIN_STAND</th><th>TAXI_ID</th><th>TIMESTAMP</th><th>DAY_TYPE</th><th>MISSING_DATA</th><th>POLYLINE</th></tr></thead><tbody><tr><td>1374839106620000649</td><td>A</td><td>31763</td><td>null</td><td>20000649</td><td>1374839106</td><td>A</td><td>false</td><td>[[-8.581896,41.180301],[-8.582706,41.180895],[-8.582733,41.180931],[-8.582157,41.181687],[-8.580843,41.18328],[-8.579268,41.184666],[-8.579736,41.185467],[-8.580177,41.185701],[-8.581032,41.186079],[-8.581779,41.185062],[-8.582472,41.18355],[-8.582553,41.182866],[-8.582877,41.1822],[-8.582895,41.182164],[-8.582913,41.182074],[-8.582922,41.182038],[-8.583003,41.181489],[-8.583498,41.180472],[-8.58429,41.178384],[-8.584974,41.177223],[-8.585217,41.176746],[-8.585622,41.175855],[-8.586306,41.174838],[-8.587359,41.172903],[-8.588493,41.171004],[-8.589762,41.169366],[-8.592219,41.167971],[-8.594262,41.167044],[-8.596764,41.16627],[-8.598879,41.165505],[-8.600085,41.164857],[-8.60049,41.164542],[-8.601615,41.163624],[-8.602299,41.16321],[-8.603532,41.162202],[-8.603784,41.16204],[-8.603784,41.162049],[-8.603793,41.162031],[-8.604306,41.161806],[-8.604972,41.161896],[-8.607042,41.162202],[-8.